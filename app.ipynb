# %%
# TODO: change this to .py file and move to script/

import numpy as np
import pandas as pd

import script.visualization

profile = pd.read_csv("data/presentation/ResultPretrain/profile.csv")
x = np.load("data/presentation/ResultPretrain/x.npy")
y = np.load("data/presentation/ResultPretrain/y.npy")

visualization =script.visualization.VisualizationRepresentation(
    x=x, y=y, profile=profile, 
    # stage="S1",
    stage="S2",
)
